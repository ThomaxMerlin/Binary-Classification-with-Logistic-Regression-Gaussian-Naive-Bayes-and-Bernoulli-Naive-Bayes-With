# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification
x,y = make_classification(n_samples=400,n_classes=2,n_features=3,n_informative=2,n_redundant=0,n_clusters_per_class=2)

# %%
x[:5,]
# Out:
# array([[-1.67689553, -1.14565773, -0.02319856],
#        [ 0.08978338,  0.19917355, -3.37982621],
#        [ 2.26048509, -1.53070571,  1.51375787],
#        [-0.05559739,  1.23480033,  1.21962754],
#        [-1.1371316 , -1.394726  ,  0.19467249]])

# %%
y.shape
# Out:
# (400,)

# %%
y[:5]
# Out:
# array([0, 0, 1, 1, 0])

# %%
x[:,0].mean()
# Out:
# -0.06890592300932291

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
figure, axes=plt.subplots(nrows=1,ncols=3,figsize=(10,4))
sns.histplot(x[:,0],kde=True,ax=axes[0])
sns.histplot(x[:,1],kde=True,ax=axes[1])
sns.histplot(x[:,2],kde=True,ax=axes[2])
# Out:
# <Axes: ylabel='Count'>

# %%
figure, axes=plt.subplots(nrows=1,ncols=3,figsize=(12,4))
sns.histplot(x[:,0],ax=axes[0])
sns.histplot(x[:,1],ax=axes[1])
sns.histplot(x[:,2],ax=axes[2])
# Out:
# <Axes: ylabel='Count'>

# %%
figure, axes=plt.subplots(nrows=1,ncols=3,figsize=(12,4))
sns.boxplot(x[:,0],ax=axes[0])
sns.boxplot(x[:,1],ax=axes[1])
sns.boxplot(x[:,2],ax=axes[2])
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB,BernoulliNB

# %%
gb=GaussianNB()
bb=BernoulliNB()
lg=LogisticRegression()
gb.fit(x_train,y_train)
bb.fit(x_train,y_train)
lg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # Train Model Accuracy

# %%
gb.score(x_train,y_train)
# Out:
# 0.9071428571428571

# %%
bb.score(x_train,y_train)
# Out:
# 0.9142857142857143

# %%
lg.score(x_train,y_train)
# Out:
# 0.925

# %% [markdown]
# # Predict Model Accuracy

# %%
y_pred1=gb.predict(x_test)
y_pred2=bb.predict(x_test)
y_pred3=lg.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from scikitplot.metrics import plot_roc_curve

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.9

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.8916666666666667

# %%
accuracy_score(y_test,y_pred3)
# Out:
# 0.9083333333333333

# %%
print(classification_report(y_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.85      0.90        65
#            1       0.84      0.96      0.90        55
#
#     accuracy                           0.90       120
#    macro avg       0.90      0.90      0.90       120
# weighted avg       0.91      0.90      0.90       120

# %%
print(classification_report(y_test,y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.83      0.89        65
#            1       0.83      0.96      0.89        55
#
#     accuracy                           0.89       120
#    macro avg       0.90      0.90      0.89       120
# weighted avg       0.90      0.89      0.89       120

# %%
print(classification_report(y_test,y_pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.86      0.91        65
#            1       0.85      0.96      0.91        55
#
#     accuracy                           0.91       120
#    macro avg       0.91      0.91      0.91       120
# weighted avg       0.91      0.91      0.91       120

# %%
figure, axes=plt.subplots(nrows=1,ncols=3,figsize=(15,4))
sns.heatmap(confusion_matrix(y_test,y_pred1),annot=True,ax=axes[0])
sns.heatmap(confusion_matrix(y_test,y_pred2),annot=True,ax=axes[1])
sns.heatmap(confusion_matrix(y_test,y_pred3),annot=True,ax=axes[2])
# Out:
# <Axes: >

# %%
fig = plt_roc_curve(gb,x_test,y_test)
fig = plt_roc_curve(bb,x_test,y_test,ax= fog.ax_)
fig = plt_roc_curve(lg,x_test,y_test,ax= fog.ax_)
fig.figure_.suptitle("ROC curve comparsion")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 fig = plt_roc_curve(gb,x_test,y_test)
#       2 fig = plt_roc_curve(bb,x_test,y_test,ax= fog.ax_)
#       3 fig = plt_roc_curve(lg,x_test,y_test,ax= fog.ax_)
#
# NameError: name 'plt_roc_curve' is not defined

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

# Assuming you have three classifiers: gb, bb, and lg

fig, ax = plt.subplots(figsize=(8, 6))  # Create a figure and axes

# Plot ROC curves for each classifier
plot_roc_curve(gb, x_test, y_test, ax=ax, name='Gradient Boosting')
plot_roc_curve(bb, x_test, y_test, ax=ax, name='Bagging')
plot_roc_curve(lg, x_test, y_test, ax=ax, name='Logistic Regression')

# Set the title and labels
ax.set_title("ROC Curve Comparison")
ax.set_xlabel("False Positive Rate")
ax.set_ylabel("True Positive Rate")

# Show the legend
ax.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 9
#       6 fig, ax = plt.subplots(figsize=(8, 6))  # Create a figure and axes
#       8 # Plot ROC curves for each classifier
# ----> 9 plot_roc_curve(gb, x_test, y_test, ax=ax, name='Gradient Boosting')
#      10 plot_roc_curve(bb, x_test, y_test, ax=ax, name='Bagging')
#      11 plot_roc_curve(lg, x_test, y_test, ax=ax, name='Logistic Regression')
#
# File ~\anaconda\envs\mbdiploma\Lib\site-packages\sklearn\utils\deprecation.py:87, in deprecated._decorate_fun.<locals>.wrapped(*args, **kwargs)
#      84 @functools.wraps(fun)
#      85 def wrapped(*args, **kwargs):
#      86     warnings.warn(msg, category=FutureWarning)
# ---> 87     return fun(*args, **kwargs)
#
# TypeError: plot_roc_curve() got an unexpected keyword argument 'name'

# %%
from sklearn.metrics import plot_roc_curve
import matplotlib.pyplot as plt

# Assuming you have three classifiers: gb, bb, and lg

fig, ax = plt.subplots(figsize=(8, 6))  # Create a figure and axes

# Plot ROC curves for each classifier
plot_roc_curve(gb, x_test, y_test, ax=ax, name='Gradient Boosting')
plot_roc_curve(bb, x_test, y_test, ax=ax, name='Bagging')
plot_roc_curve(lg, x_test, y_test, ax=ax, name='Logistic Regression')

# Set the title and labels
ax.set_title("ROC Curve Comparison")
ax.set_xlabel("False Positive Rate")
ax.set_ylabel("True Positive Rate")

# Show the legend
ax.legend()

plt.show()
